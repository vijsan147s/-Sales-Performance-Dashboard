# %% [markdown]
# # Data Cleaning using the python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("sales_data.csv")

# %%
df.head()
# Out:
#    Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0        1052  2023-02-03       Bob  North       5053.97             18
# 1        1093  2023-04-21       Bob   West       4384.02             17
# 2        1015  2023-09-21     David  South       4631.23             30
# 3        1072  2023-08-24       Bob  South       2167.94             39
# 4        1061  2023-03-24   Charlie   East       3750.20             13
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   Payment_Method Sales_Channel Region_and_Sales_Rep
# 0           Cash        Online            North-Bob
# 1           Cash        Retail             West-Bob
# 2  Bank Transfer        Retail          South-David
# 3    Credit Card        Retail            South-Bob
# 4    Credit Card        Online         East-Charlie

# %%
df.tail()
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 995             Food    4943.03     5442.15     Returning      0.29
# 996         Clothing    1754.32     1856.40           New      0.21
# 997         Clothing     355.72      438.27     Returning      0.06
# 998      Electronics    3685.03     3743.39           New      0.01
# 999             Food    2632.58     2926.68     Returning      0.14
#
#     Payment_Method Sales_Channel Region_and_Sales_Rep
# 995           Cash        Online        North-Charlie
# 996  Bank Transfer        Retail            North-Bob
# 997  Bank Transfer        Online          South-David
# 998  Bank Transfer        Online           West-David
# 999           Cash        Online           East-Alice

# %%
df.shape
# Out:
# (1000, 14)

# %%
df = pd.read_csv("sales_data.csv")

# %%
df.columns
# Out:
# Index(['Product_ID', 'Sale_Date', 'Sales_Rep', 'Region', 'Sales_Amount',
#        'Quantity_Sold', 'Product_Category', 'Unit_Cost', 'Unit_Price',
#        'Customer_Type', 'Discount', 'Payment_Method', 'Sales_Channel',
#        'Region_and_Sales_Rep'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Product_ID            1000 non-null   int64
#  1   Sale_Date             1000 non-null   object
#  2   Sales_Rep             1000 non-null   object
#  3   Region                1000 non-null   object
#  4   Sales_Amount          1000 non-null   float64
#  5   Quantity_Sold         1000 non-null   int64
#  6   Product_Category      1000 non-null   object
#  7   Unit_Cost             1000 non-null   float64
#  8   Unit_Price            1000 non-null   float64
#  9   Customer_Type         1000 non-null   object
#  10  Discount              1000 non-null   float64
#  11  Payment_Method        1000 non-null   object
#  12  Sales_Channel         1000 non-null   object
#  13  Region_and_Sales_Rep  1000 non-null   object
# dtypes: float64(4), int64(2), object(8)
# memory usage: 109.5+ KB

# %%
df.describe()
# Out:
#         Product_ID  Sales_Amount  Quantity_Sold    Unit_Cost   Unit_Price  \
# count  1000.000000   1000.000000    1000.000000  1000.000000  1000.000000
# mean   1050.128000   5019.265230      25.355000  2475.304550  2728.440120
# std      29.573505   2846.790126      14.159006  1417.872546  1419.399839
# min    1001.000000    100.120000       1.000000    60.280000   167.120000
# 25%    1024.000000   2550.297500      13.000000  1238.380000  1509.085000
# 50%    1051.000000   5019.300000      25.000000  2467.235000  2696.400000
# 75%    1075.000000   7507.445000      38.000000  3702.865000  3957.970000
# max    1100.000000   9989.040000      49.000000  4995.300000  5442.150000
#
#          Discount
# count  1000.00000
# mean      0.15239
# std       0.08720
# min       0.00000
# 25%       0.08000
# 50%       0.15000
# 75%       0.23000
# max       0.30000

# %%
df.dtypes
# Out:
# Product_ID                int64
# Sale_Date                object
# Sales_Rep                object
# Region                   object
# Sales_Amount            float64
# Quantity_Sold             int64
# Product_Category         object
# Unit_Cost               float64
# Unit_Price              float64
# Customer_Type            object
# Discount                float64
# Payment_Method           object
# Sales_Channel            object
# Region_and_Sales_Rep     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Product_ID              0
# Sale_Date               0
# Sales_Rep               0
# Region                  0
# Sales_Amount            0
# Quantity_Sold           0
# Product_Category        0
# Unit_Cost               0
# Unit_Price              0
# Customer_Type           0
# Discount                0
# Payment_Method          0
# Sales_Channel           0
# Region_and_Sales_Rep    0
# dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.columns = df.columns.str.strip()

df.columns = df.columns.str.lower()

# %%
sns.boxplot(df['sales_amount'])
# Out:
# <Axes: ylabel='sales_amount'>

# %%
df['sales_amount'].sum()
# Out:
# np.float64(5019265.2299999995)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

# %%
df = pd.read_csv("Sales_Data.csv")

# %%
df['Profit'] = (df['Unit_Price'] - df['Unit_Cost']) * df['Quantity_Sold']

# %%
df['Profit_Margin'] = (df['Profit']/df['Sales_Amount'])*100

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
df['Sales_Amount'].sum()
# Out:
# np.float64(5019265.23)

# %%
df.shape[0]
# Out:
# 1000

# %%
df['Quantity_Sold'].sum()
# Out:
# np.int64(25355)

# %%
df['Sales_Amount'].mean()
# Out:
# np.float64(5019.265230000001)

# %%
df['Sales_Amount'].median()
# Out:
# np.float64(5019.3)

# %%
df['Profit'].sum()
# Out:
# np.float64(6487847.07)

# %% [markdown]
# # Sales Analysis

# %%
df.groupby('Region')['Sales_Amount'].sum()
# Out:
# Region
# East     1259792.93
# North    1369612.51
# South    1154250.86
# West     1235608.93
# Name: Sales_Amount, dtype: float64

# %%
df.groupby('Sales_Rep')['Sales_Amount'].sum()
# Out:
# Sales_Rep
# Alice       965541.77
# Bob        1080990.63
# Charlie     860811.48
# David      1141737.36
# Eve         970183.99
# Name: Sales_Amount, dtype: float64

# %%
sns.barplot(x='Region', y='Sales_Amount', data=df)
# Out:
# <Axes: xlabel='Region', ylabel='Sales_Amount'>

# %%
df.groupby('Product_Category')['Sales_Amount'].sum()
# Out:
# Product_Category
# Clothing       1313474.36
# Electronics    1243499.64
# Food           1201773.54
# Furniture      1260517.69
# Name: Sales_Amount, dtype: float64

# %%
df.groupby('Customer_Type')['Sales_Amount'].sum()
# Out:
# Customer_Type
# New          2506258.30
# Returning    2513006.93
# Name: Sales_Amount, dtype: float64

# %%
df.groupby('Payment_Method')['Sales_Amount'].sum()
# Out:
# Payment_Method
# Bank Transfer    1717363.17
# Cash             1544338.54
# Credit Card      1757563.52
# Name: Sales_Amount, dtype: float64

# %%
df.groupby('Sales_Channel')['Sales_Amount'].sum()
# Out:
# Sales_Channel
# Online    2458833.93
# Retail    2560431.30
# Name: Sales_Amount, dtype: float64

# %% [markdown]
# # Discount Analysis

# %%
df['Discount'].mean()
# Out:
# np.float64(0.15239)

# %%
sns.scatterplot(
    x='Discount',
    y='Sales_Amount',
    data=df
)
# Out:
# <Axes: xlabel='Discount', ylabel='Sales_Amount'>

# %% [markdown]
# # Profit Analysis

# %%
df.groupby('Product_Category')['Profit'].sum()
# Out:
# Product_Category
# Clothing       1712957.80
# Electronics    1574320.06
# Food           1421108.05
# Furniture      1779461.16
# Name: Profit, dtype: float64

# %%
df.groupby('Region')['Profit'].sum()
# Out:
# Region
# East     1650557.20
# North    1661461.20
# South    1519736.90
# West     1656091.77
# Name: Profit, dtype: float64

# %%
df.groupby('Sales_Rep')['Profit'].sum()
# Out:
# Sales_Rep
# Alice      1294822.01
# Bob        1170800.24
# Charlie    1071393.16
# David      1501749.76
# Eve        1449081.90
# Name: Profit, dtype: float64

# %%
corr = df.corr(numeric_only=True)

sns.heatmap(corr,
            annot=True,
            cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.boxplot(df['Sales_Amount'])
# Out:
# <Axes: ylabel='Sales_Amount'>

# %%
sns.boxplot(df['Profit'])
# Out:
# <Axes: ylabel='Profit'>

# %%
df.nlargest(10,'Sales_Amount')
# Out:
#      S.NO.   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 376   1036  10-12-2023     David  North       9989.04              7
# 493   1050  21-08-2023     David  North       9976.52             17
# 777   1079  24-08-2023     Alice  North       9972.66              8
# 746   1075  15-08-2023   Charlie  North       9972.11             28
# 166   1016  23-04-2023     David  South       9961.96              6
# 647   1063  14-08-2023       Bob  North       9956.75             27
# 974   1099  14-04-2023     Alice   East       9948.71             27
# 861   1089  19-10-2023       Eve   West       9933.22             23
# 147   1015  22-09-2023     David  South       9914.15             22
# 105   1010  12-10-2023   Charlie  North       9907.72             20
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 376             Food    2882.25     3163.70     Returning      0.05
# 493        Furniture    2346.80     2654.65           New      0.13
# 777         Clothing    3808.23     3891.62     Returning      0.26
# 746         Clothing    2570.22     2610.84     Returning      0.27
# 166        Furniture    4502.09     4879.72           New      0.13
# 647         Clothing    3760.25     4147.11           New      0.22
# 974             Food    4929.55     4990.33     Returning      0.29
# 861             Food    2120.54     2597.67     Returning      0.26
# 147      Electronics    4275.59     4576.72     Returning      0.02
# 105        Furniture    4298.74     4475.19     Returning      0.16
#
#     Payment_Method Sales_Channel Region_and_Sales_Rep    Profit  Profit_Margin
# 376           Cash        Retail          North-David   1970.15      19.723117
# 493           Cash        Retail          North-David   5233.45      52.457671
# 777  Bank Transfer        Online          North-Alice    667.12       6.689489
# 746  Bank Transfer        Retail        North-Charlie   1137.36      11.405410
# 166    Credit Card        Online          South-David   2265.78      22.744319
# 647           Cash        Online            North-Bob  10445.22     104.905918
# 974    Credit Card        Online           East-Alice   1641.06      16.495204
# 861    Credit Card        Retail             West-Eve  10973.99     110.477670
# 147           Cash        Retail          South-David   6624.86      66.822269
# 105           Cash        Online        North-Charlie   3529.00      35.618689

# %%
df.nsmallest(10,'Sales_Amount')
# Out:
#      S.NO.   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 705   1070  13-12-2023     Alice   West        100.12              8
# 658   1064  19-12-2023     Alice   West        106.47             35
# 767   1078  16-11-2023     David   East        113.40              8
# 675   1067  29-06-2023       Eve  South        114.59             48
# 844   1087  08-09-2023   Charlie  North        119.72             20
# 56    1005  28-11-2023     David   West        152.60             43
# 851   1088  18-10-2023       Eve   West        177.63             16
# 152   1015  24-09-2023       Bob   East        182.37             35
# 101   1009  29-01-2023       Eve   West        182.80             16
# 711   1071  30-10-2023     Alice   West        189.48             22
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 705         Clothing    3762.27     4166.95     Returning      0.16
# 658         Clothing    4900.03     5118.83     Returning      0.07
# 767        Furniture    3459.61     3657.23     Returning      0.03
# 675             Food    4319.32     4625.56     Returning      0.10
# 844         Clothing     193.27      297.69           New      0.22
# 56         Furniture    1200.40     1430.45           New      0.08
# 851        Furniture    3016.90     3040.73           New      0.26
# 152         Clothing    3461.15     3631.75     Returning      0.27
# 101         Clothing    3745.69     3883.77     Returning      0.18
# 711      Electronics    2701.39     3185.81           New      0.01
#
#     Payment_Method Sales_Channel Region_and_Sales_Rep    Profit  Profit_Margin
# 705  Bank Transfer        Online           West-Alice   3237.44    3233.559728
# 658    Credit Card        Retail           West-Alice   7658.00    7192.636423
# 767  Bank Transfer        Online           East-David   1580.96    1394.144621
# 675  Bank Transfer        Online            South-Eve  14699.52   12827.925648
# 844           Cash        Online        North-Charlie   2088.40    1744.403608
# 56   Bank Transfer        Retail           West-David   9892.15    6482.404980
# 851  Bank Transfer        Retail             West-Eve    381.28     214.648427
# 152    Credit Card        Online             East-Bob   5971.00    3274.113067
# 101  Bank Transfer        Retail             West-Eve   2209.28    1208.577681
# 711  Bank Transfer        Online           West-Alice  10657.24    5624.466962

# %%
df.groupby('Sales_Rep')['Sales_Amount'].sum().sort_values(ascending=False)
# Out:
# Sales_Rep
# David      1141737.36
# Bob        1080990.63
# Eve         970183.99
# Alice       965541.77
# Charlie     860811.48
# Name: Sales_Amount, dtype: float64
